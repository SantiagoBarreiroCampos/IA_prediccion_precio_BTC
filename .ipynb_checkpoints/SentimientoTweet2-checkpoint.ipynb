# %%
import re
import tweepy
from tweepy import OAuthHandler
from textblob import TextBlob
  
class TwitterClient(object):
    '''
    Clase generica de twitter para análisis de sentimientos.
    '''
    def __init__(self):
        '''
        Constructor de la clase.
        '''
        # Keys y tokens de twitter
        consumer_key = 'PUu8BHhHDfWpNfadkpJsvPta3'
        consumer_secret = '5fteblsaniYcP3un0eLTKt9jMDkCyK3Op4NELGQITst5pVPrbw'
        access_token = '1448336514455330827-o77jYvZmmXLT9qsEsK94ZKqwFHIqBl'
        access_token_secret = 'Nsqmn1jMDoNA5XN3KMSc7NvlIFjfoekvisZmmXRw2L48U'
  
        # intenta autenticacion
        try:
            self.auth = OAuthHandler(consumer_key, consumer_secret)
            self.auth.set_access_token(access_token, access_token_secret)
            self.api = tweepy.API(self.auth)
        except:
            print("Error: Autenticacion Fallida")
  
    def clean_tweet(self, tweet):
        '''
        Function para limpiar el texto de un tweet quitando los links y caracteres especiales
        usando regex simples.
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())
  
    def get_tweet_sentiment(self, tweet):
        '''
        Funcion para clasificar los sentimientos del tweet pasado como parametro
        usando los metodos de sentimientos de textblob
        '''
        # crear un objeto TextBlob con el texto del tweet
        analisis = TextBlob(self.clean_tweet(tweet))
        # clasificar sentimiento
        if analisis.sentiment.polarity > 0:
            return 'positivo'
        elif analisis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negativo'
  
    def get_tweets(self, query, count = 10):
        '''
        Funcion para capturar tweets y parsearlos.
        '''
        # lista vacia para guardar tweets
        tweets = []
  
        try:
            # llama a la api de twitter para buscar tweets
            tweets_buscados = self.api.search_tweets(q = query, count = count)
  
            # parsear los tweets uno por uno
            for tweet in tweets_buscados:
                # diccionario vacio para guardar los parametros requeridos de un tweet
                tweets_parseados = {}
  
                # guardar el texto
                tweets_parseados['texto'] = tweet.text
                # guardar el sentimiento
                tweets_parseados['sentimiento'] = self.get_tweet_sentiment(tweet.text)
  
                # añadir el tweet analizado a la lista de tweets
                if tweet.retweet_count > 0:
                    # si el tweet tiene retweets se asegura de que se añade solo una vez
                    if tweets_parseados not in tweets:
                        tweets.append(tweets_parseados)
                else:
                    tweets.append(tweets_parseados)
  
            # devuelve los tweets parseados
            return tweets
  
        except tweepy.TweepError as e:
            print("Error : " + str(e))
  
def main():
    # crea un objeto de la clase TwitterClient
    api = TwitterClient()
    # llama a la funcion de capturar tweets
    tweets = api.get_tweets(query = 'Bitcoin', count = 300)
  
    # selecciona los tweets positivos de la lista
    ptweets = [tweet for tweet in tweets if tweet['sentimiento'] == 'positivo']
    # porcentaje de tweets Positivos
    print("Porcentaje de tweets Positivos: {} %".format(100*len(ptweets)/len(tweets)))
    
    # selecciona los tweets negativos de la lista
    ntweets = [tweet for tweet in tweets if tweet['sentimiento'] == 'negativo']
    # porcentaje de tweets Negativos
    print("Porcentaje de tweets Negativos: {} %".format(100*len(ntweets)/len(tweets)))
    
    # porcentaje de tweets Neutros
    print("Porcentaje de tweets Neutros: {} % \
        ".format(100*(len(tweets) -(len( ntweets )+len( ptweets)))/len(tweets)))
  
    # Imprime los 5 primeros tweets positivos
    print("\n\nTWEETS POSITIVOS:")
    for tweet in ptweets[:5]:
        print("\nTexto: ")
        print(tweet['texto'])
  
    # Imptime los 5 primeros tweets negativos
    print("\n\nTWEETS NEGATIVOS:")
    for tweet in ntweets[:5]:
        print("\nTexto: ")
        print(tweet['texto'])
  
if __name__ == "__main__":
    # llama a la funcion main
    main()
# Out:
# Porcentaje de tweets Positivos: 34.78260869565217 %
# Porcentaje de tweets Negativos: 6.521739130434782 %
# Porcentaje de tweets Neutros: 58.69565217391305 %
#
#
# TWEETS POSITIVOS:
#
# Texto:
# @AirdropStario Good  project
# @Rakib0166
# @AnamulH203040
# @Rajonha38905837
# #cryptocurrency #Airdrop #BSC #Bitcoin… https://t.co/vNEPBgbqpd
#
# Texto:
# Buy Crypto With Your Credit Card / Fast Crypto Exchange
#
# https://t.co/GwaCvQyQbc
#
# #Bitcoin #BTC #ETH #XRP #Crypto… https://t.co/5B2E9ZZlSI
#
# Texto:
# @Rager @gator_bitcoin We don't  buy bitcoin
# We earn bitcoin From Mining
# I'm ready to show 10 lucky people on how t… https://t.co/7E8ph15O4c
#
# Texto:
# RT @bitfinex: We're excited to share our collaboration with the Republic of El Salvador to build the digital securities infrastructure and…
#
# Texto:
# RT @GoingParabolic: 2022 - The year people move places based on smart young leaders making good decisions that are truly in the best intere…
#
#
# TWEETS NEGATIVOS:
#
# Texto:
# Bitcoin down to $ 58k range. +0.7% change in 24h.  #bitcoin #btc
#
# Texto:
# @lilyxbtc Thank God for fucking and #bitcoin.
#
# Texto:
# RT @AirdropStario: 💧 UniX 2nd Round Airdrop 💧
#
# 🏆 Task:          ➕ 100,000 UniX (~$100,000) » Total airdrop pool.
#
# 👨‍👩‍👧 Referral:   ➕ 10 Po…
#
# Texto:
# @hmichellerose There are some pretty serious challenges ahead, but it’s hard not to be a bit optimistic. Bitcoin do… https://t.co/he9eJtr3as
#
# Texto:
# RT @JohalMiles: There is no other asset on the planet in which your worst case scenario is to hodl for 3 years to be in immense profits.
#
# B…
